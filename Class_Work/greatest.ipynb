# %% [markdown]
# <a href="https://colab.research.google.com/github/rkpraj1536/PythonWork/blob/main/greatest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#given number
num=3723
max=0
while(num>0):
  digit=num%10 #get last digit
  if(digit>max):#checking digit is greater or not
    max=digit
  num=num//10   #remove last digit
print("greatest digit is :",max)
# Out:
# greatest digit is : 7

# %%
from google.colab import drive
drive.mount('/content/drive')
