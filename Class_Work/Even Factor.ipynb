# %% [markdown]
# <a href="https://colab.research.google.com/github/rkpraj1536/PythonWork/blob/main/Even%20Factor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

print("Even factors of", num, "are:")

for i in range(1, num + 1):
    if num % i == 0 and i % 2 == 0:
        print(i)
